# %% [markdown]
# # Gradient Boosting Classifier

# %%
# importing stuff

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
import numpy as np

# First, im gonna load the dataset

data = {
    'disease': [
        'Common Cold', 'Influenza', 'Diabetes Mellitus Type 2', 'Hypertension', 'Asthma',
        'Chronic Obstructive Pulmonary Disease', 'Heart Attack', 'Stroke', 'Migraine', 'Allergies',
        'Gastroesophageal Reflux Disease', 'Irritable Bowel Syndrome', 'Rheumatoid Arthritis', 'Osteoarthritis',
        'Psoriasis', 'Tuberculosis', 'Hepatitis B', 'Hepatitis C', 'HIV/AIDS', 'Cancer', 'Depression',
        'Anxiety Disorders', 'Schizophrenia', 'Parkinson’s Disease', 'Alzheimer’s Disease', 'Pneumonia',
        'Bronchitis', 'Cystic Fibrosis', 'Strep Throat', 'Chickenpox', 'Mononucleosis', 'Chikungunya', 'Malaria',
        'Dengue Fever', 'Ebola', 'Zika Virus', 'Lyme Disease', 'Lupus',
        'Multiple Sclerosis', 'Celiac Disease', 'Crohn’s Disease', 'Ulcerative Colitis', 'Gout',
        'Anemia', 'Leukemia', 'Lymphoma', 'Skin Cancer', 'Melanoma',
        'Tetanus', 'Rabies', 'Polio', 'Measles', 'Rubella',
        'Meningitis', 'Sepsis', 'Tonsillitis', 'Sinusitis', 'Pleurisy',
        'Kidney Stones', 'Urinary Tract Infection', 'Gallstones', 'Pancreatitis', 'Liver Cirrhosis',
        'Hyperthyroidism', 'Hypothyroidism', 'Fibromyalgia', 'Sleep Apnea', 'Chronic Fatigue Syndrome',
        'Sickle Cell Disease', 'Epilepsy', 'Hemophilia', 'Gastritis', 'Diverticulitis', 'Bacterial Vaginosis', 
        'Endometriosis', 'Prostate Cancer', 'Testicular Cancer', 'Ovarian Cancer', 'Cervical Cancer', 
        'Pelvic Inflammatory Disease', 'Chronic Kidney Disease', 'Acute Kidney Failure', 'Gallbladder Disease', 
        'Peptic Ulcer Disease', 'Thyroid Cancer', 'Pancreatic Cancer', 'Bipolar Disorder', 'Post-Traumatic Stress Disorder (PTSD)', 
        'Obsessive-Compulsive Disorder (OCD)', 'Attention-Deficit/Hyperactivity Disorder (ADHD)', 'Autism Spectrum Disorder (ASD)', 
        'Alcohol Use Disorder', 'Drug Use Disorder', 'Anorexia Nervosa', 'Bulimia Nervosa', 'Vasculitis', 
        'Eczema', 'Hyperparathyroidism', 'Hypoparathyroidism', 'Bell’s Palsy', 'Hemochromatosis'
    ],
    'symptoms': [
        'Runny nose, sore throat, cough, sneezing, mild fever, headache',
        'High fever, chills, muscle aches, fatigue, cough, sore throat, headache',
        'Frequent urination, excessive thirst, unexplained weight loss, fatigue, blurred vision, slow-healing sores',
        'Headaches, shortness of breath, nosebleeds, dizziness, chest pain',
        'Wheezing, shortness of breath, chest tightness, coughing, difficulty breathing during physical activity',
        'Persistent cough, shortness of breath, wheezing, chest tightness, frequent respiratory infections',
        'Chest pain or discomfort, pain in the shoulder, neck, or jaw, shortness of breath, nausea or vomiting, lightheadedness, cold sweat',
        'Sudden numbness or weakness in the face, arm, or leg, sudden confusion or trouble speaking, sudden trouble seeing, sudden trouble walking, dizziness, loss of balance',
        'Severe headache, nausea, vomiting, sensitivity to light and sound, visual disturbances',
        'Sneezing, runny or stuffy nose, itchy or watery eyes, skin rash or hives, itchy throat or ears',
        'Heartburn, regurgitation, chest pain, difficulty swallowing, chronic cough',
        'Abdominal pain or cramping, bloating, gas, diarrhea or constipation, changes in bowel habits',
        'Joint pain and swelling, morning stiffness, fatigue, fever, weight loss',
        'Joint pain, stiffness, swelling, decreased range of motion, bone spurs',
        'Red patches of skin covered with thick, silvery scales, dry, cracked skin, itching or soreness, swollen and stiff joints',
        'Persistent cough, chest pain, weight loss, fever, night sweats',
        'Fatigue, abdominal pain, loss of appetite, nausea and vomiting, dark urine, jaundice',
        'Fatigue, abdominal pain, loss of appetite, nausea, jaundice, dark urine',
        'Flu-like symptoms, rapid weight loss, recurring fever, persistent cough, night sweats, sores or ulcers',
        'Unexplained weight loss, fever, fatigue, pain, skin changes, persistent cough or hoarseness',
        'Persistent sadness, loss of interest or pleasure, fatigue, changes in appetite or weight, trouble sleeping, feelings of worthlessness',
        'Excessive worry, restlessness, fatigue, difficulty concentrating, muscle tension, sleep disturbances',
        'Delusions, hallucinations, disorganized thinking, negative symptoms',
        'Tremors, muscle rigidity, bradykinesia, postural instability, difficulty with balance',
        'Memory loss, difficulty performing familiar tasks, disorientation, poor judgment, changes in mood and personality', 
        'Cough, fever, chills, shortness of breath, chest pain, fatigue',
        'Cough with mucus, fatigue, shortness of breath, slight fever, chest discomfort',
        'Salty-tasting skin, persistent cough with thick mucus, lung infections, poor growth, difficulty breathing',
        'Severe sore throat, difficulty swallowing, swollen lymph nodes, fever, headache',
        'Itchy, blister-like rash, fever, tiredness, loss of appetite, headache',
        'Extreme fatigue, sore throat, fever, swollen lymph nodes, headache',
        'High fever, joint pain, rash, headache, muscle pain, fatigue',
        'Fever, chills, headache, muscle pain, fatigue, nausea, vomiting',
        'High fever, severe headache, pain behind the eyes, joint and muscle pain, fatigue, nausea, rash',
        'Fever, severe headache, muscle pain, weakness, diarrhea, vomiting, unexplained bleeding or bruising',
        'Fever, rash, joint pain, red eyes, headache, muscle pain',
        'Fever, headache, fatigue, muscle and joint pain, swollen lymph nodes, rash at the site of the tick bite',
        'Fatigue, joint pain, skin rash, fever, photosensitivity, hair loss',
        'Numbness or weakness in limbs, vision problems, tingling or pain, tremors, fatigue, dizziness',
        'Abdominal pain, bloating, diarrhea, weight loss, fatigue, rash, mouth ulcers',
        'Abdominal pain, diarrhea, fatigue, weight loss, mouth sores, reduced appetite',
        'Abdominal pain, diarrhea with blood or pus, urgency to defecate, weight loss, fatigue, fever',
        'Sudden, intense joint pain, redness, tenderness, swelling, often in the big toe',
        'Fatigue, weakness, pale or yellowish skin, irregular heartbeat, shortness of breath, dizziness, cold hands and feet',
        'Fatigue, frequent infections, fever, easy bruising, bone pain, weight loss',
        'Painless swelling of lymph nodes, fever, night sweats, weight loss, fatigue, itching',
        'A new growth or sore that doesn’t heal, changes in the appearance of moles, scaly or crusted growths',
        'Changes in an existing mole, a large brownish spot, a painful lesion that may itch or burn',
        'Jaw cramping, muscle spasms, stiffness, difficulty swallowing, seizures, fever, sweating',
        'Fever, headache, anxiety, confusion, excessive salivation, hallucinations, paralysis, hydrophobia',
        'Fever, sore throat, headache, vomiting, fatigue, back pain, stiffness in the neck and limbs, paralysis',
        'High fever, cough, runny nose, watery eyes, rash of flat red spots that start on the face and spread downward',
        'Mild fever, rash, joint pain, headache, red eyes, swollen lymph nodes',
        'Fever, headache, stiff neck, sensitivity to light, nausea, vomiting, confusion, seizures',
        'Fever, chills, rapid breathing, rapid heart rate, confusion, rash',
        'Sore throat, difficulty swallowing, fever, bad breath, swollen lymph nodes in the neck',
        'Facial pain, pressure, headache, nasal congestion, runny nose, sore throat, cough, fatigue',
        'Sharp, stabbing chest pain that worsens with deep breathing, coughing, or sneezing, shortness of breath, dry cough',
        'Severe pain in the back or side, pain during urination, nausea, vomiting, blood in urine',
        'Painful urination, frequent urination, urgency to urinate, cloudy or bloody urine, lower abdominal pain',
        'Sudden intense pain in the upper right abdomen, nausea, vomiting, fever, jaundice',
        'Severe abdominal pain, nausea, vomiting, fever, rapid pulse, tenderness when touching the abdomen',
        'Fatigue, nausea, weight loss, itchy skin, jaundice, swelling in the legs and abdomen, confusion',
        'Unintentional weight loss, rapid heartbeat, nervousness, irritability, tremors, sweating, heat intolerance',
        'Fatigue, weight gain, sensitivity to cold, constipation, dry skin, hair loss, depression',
        'Widespread musculoskeletal pain, fatigue, sleep disturbances, memory and mood issues',
        'Loud snoring, episodes of stopped breathing during sleep, waking up gasping, daytime fatigue, morning headaches',
        'Severe fatigue, headaches, muscle and joint pain, difficulty concentrating, sore throat, unrefreshing sleep',
        'Episodes of pain, fatigue, swelling of the hands and feet, frequent infections, delayed growth', 
        'Seizures, temporary confusion, staring spells, loss of consciousness, psychic symptoms, uncontrollable movements',
        'Prolonged bleeding, spontaneous bleeding, excessive bruising, joint pain or swelling',
        'Abdominal pain, bloating, nausea, vomiting, indigestion, loss of appetite',
        'Abdominal pain, cramping, bloating, fever, nausea, constipation or diarrhea',
        'Unusual vaginal discharge with a strong odor, itching, burning during urination',
        'Pelvic pain, heavy menstrual periods, pain during intercourse, infertility, fatigue',
        'Difficulty urinating, weak urine stream, blood in urine, pelvic discomfort, bone pain, erectile dysfunction',
        'A lump in the testicle, a feeling of heaviness in the scrotum, dull ache in the lower abdomen or groin',
        'Abdominal bloating or swelling, quickly feeling full when eating, weight loss, pelvic discomfort',
        'Abnormal vaginal bleeding, unusual discharge, pelvic pain, pain during intercourse',
        'Lower abdominal pain, fever, unusual discharge with an odor, painful urination, pain during intercourse',
        'Fatigue, swelling in legs, nausea, difficulty sleeping, frequent urination, high blood pressure',
        'Decreased urine output, swelling in legs or feet, fatigue, confusion, shortness of breath, nausea',
        'Sharp pain in the upper right abdomen, nausea, vomiting, indigestion, bloating, fever',
        'Burning stomach pain, bloating, heartburn, nausea, intolerance to fatty foods, stomach bleeding',
        'A lump or swelling in the neck, difficulty swallowing, hoarseness, shortness of breath',
        'Upper abdominal pain that radiates to the back, loss of appetite, unintended weight loss, yellowing of skin and eyes (jaundice)',
        'Periods of depression, periods of elevated mood or irritability, impulsive behavior, poor decision-making, restlessness',
        'Nightmares, flashbacks, severe anxiety, uncontrollable thoughts about the traumatic event, irritability, emotional numbness',
        'Uncontrollable, recurring thoughts or behaviors, excessive hand washing, arranging things in a specific order, checking locks repeatedly',
        'Inattention, hyperactivity, impulsiveness, trouble focusing, fidgeting, difficulty staying organized',
        'Difficulty in communication, repetitive behaviors, restricted interests, difficulty with social interaction, sensory sensitivities',
        'Inability to limit drinking, withdrawal symptoms when not drinking, continuing to drink despite harm to health or relationships',
        'Compulsive drug-seeking behavior, withdrawal symptoms, using drugs despite negative effects on health and relationships',
        'Extremely low body weight, intense fear of gaining weight, distorted body image, denial of the seriousness of low body weight',
        'Binge eating followed by purging, self-induced vomiting, excessive use of laxatives or diuretics, obsession with weight and body shape',
        'Fatigue, fever, weight loss, muscle and joint pain, rashes, numbness, tingling, vision problems',
        'Itchy, red, inflamed skin, dry patches, cracked skin, blisters, peeling skin',
        'Fatigue, muscle weakness, frequent urination, joint pain, kidney stones, abdominal pain',
        'Muscle cramps, twitching, fatigue, dry skin, brittle nails, tingling in fingers and toes',
        'Sudden weakness or paralysis on one side of the face, drooping mouth or eye, drooling, difficulty closing the eye',
        'Fatigue, joint pain, abdominal pain, liver disease, skin darkening, diabetes'
        
    ]
}
df = pd.DataFrame(data)

# Converting text data into numerical format
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['symptoms'])
y = df['disease']

# Spliting the data into two sets, one for training and the other for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

# Training the Gradient Boosting Classifier model
model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(X_train, y_train)


# Saving the model and vectorizer
joblib.dump(model, 'disease_predictor_gb_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')

def predict_diseases(user_symptoms):

    model = joblib.load('disease_predictor_gb_model.pkl')
    vectorizer = joblib.load('vectorizer.pkl')
    
    user_symptoms_vec = vectorizer.transform([user_symptoms])
    
    probabilities = model.predict_proba(user_symptoms_vec)[0]
    
    top_indices = np.argsort(probabilities)[-3:][::-1]

    diseases = np.array(model.classes_)[top_indices]
    probs = probabilities[top_indices]

    result = {disease: f"{prob * 100:.2f}% chance" for disease, prob in zip(diseases, probs)}
    return result

import re

# So in order to make sure the model does not get any random input, we are gonna check the user input and
# make sure it only contains valid symptom words. This is a pretty basic approach for simplicity. If I were
# to actually implement this model, I would do a more comprehensive check (eg. remove stopwords etc.) 

valid_symptoms = set([
    'fever', 'cough', 'fatigue', 'headache', 'sore', 'throat', 'pain', 'shortness', 'breath', 'nausea', 
    'vomiting', 'diarrhea', 'muscle', 'joint', 'rash', 'blurry', 'vision', 'swelling', 'dizziness', 
    'chest', 'tightness', 'runny', 'nose', 'sneezing', 'stomach', 'cramping', 'bloating', 'infection', 
    'weight', 'loss', 'appetite', 'itching', 'sensitivity', 'skin', 'swollen', 'lymph', 'nodes', 'blood',
    'discomfort', 'sweating', 'burning', 'intolerance', 'light', 'constipation', 'diabetes', 'difficulty',
    'chills', 'excessive thirst', 'frequent urination', 'blurred vision', 'slow-healing sores',
    'nosebleeds', 'wheezing', 'shoulder pain', 'neck pain', 'jaw pain', 'numbness', 'weakness', 
    'confusion', 'trouble speaking', 'trouble seeing', 'trouble walking', 'loss of balance',
    'sensitivity to light', 'visual disturbances', 'watery eyes', 'hives', 'heartburn',
    'regurgitation', 'difficulty swallowing', 'gas', 'changes in bowel habits', 'morning stiffness',
    'bone spurs', 'silvery scales', 'dry cracked skin', 'night sweats', 'dark urine', 'jaundice', 
    'recurring fever', 'sores', 'hoarseness', 'unexplained bleeding', 'photosensitivity', 'hair loss',
    'tingling', 'seizures', 'bruising', 'pelvic pain', 'infertility', 'erectile dysfunction',
    'lump in testicle', 'bloating', 'odor', 'high blood pressure', 'yellowing of skin', 'flashbacks',
    'withdrawal symptoms', 'distorted body image', 'self-induced vomiting', 'skin darkening',
    'muscle cramps', 'twitching', 'dry skin', 'drooping mouth', 'drooping eye'
])

def validate_input(user_input):
    # Convert the input to lowercase and remove non-alphabetic characters
    cleaned_input = re.sub(r'[^a-zA-Z\s]', '', user_input.lower())
    
    # Split the cleaned input into individual words
    symptom_words = cleaned_input.split()
    
    # Check if all the words are valid symptoms
    invalid_words = [word for word in symptom_words if word not in valid_symptoms]
    
    if invalid_words:
        print(f"Invalid words found in input: {', '.join(invalid_words)}. Please enter valid symptoms.")
        return False
    return True



user_input = input("Enter your symptoms: ")

if validate_input(user_input):
    predicted_diseases = predict_diseases(user_input)
    print("Predicted diseases and their chances:")
    for disease, chance in predicted_diseases.items():
        print(f"{disease}: {chance}")
else:
    print("Please enter symptoms using valid medical terms.")
# Out:
# Enter your symptoms:  cough, fever, headache, sore throat
# Predicted diseases and their chances:
# Pneumonia: 99.90% chance
# Malaria: 0.02% chance
# Strep Throat: 0.01% chance

# %% [markdown]
# # Random Forest Classifier

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
import numpy as np

# Load the dataset
data = {
    'disease': [
        'Common Cold', 'Influenza', 'Diabetes Mellitus Type 2', 'Hypertension', 'Asthma',
        'Chronic Obstructive Pulmonary Disease', 'Heart Attack', 'Stroke', 'Migraine', 'Allergies',
        'Gastroesophageal Reflux Disease', 'Irritable Bowel Syndrome', 'Rheumatoid Arthritis', 'Osteoarthritis',
        'Psoriasis', 'Tuberculosis', 'Hepatitis B', 'Hepatitis C', 'HIV/AIDS', 'Cancer', 'Depression',
        'Anxiety Disorders', 'Schizophrenia', 'Parkinson’s Disease', 'Alzheimer’s Disease', 'Pneumonia',
        'Bronchitis', 'Cystic Fibrosis'
    ],
    'symptoms': [
        'Runny nose, sore throat, cough, sneezing, mild fever, headache',
        'High fever, chills, muscle aches, fatigue, cough, sore throat, headache',
        'Frequent urination, excessive thirst, unexplained weight loss, fatigue, blurred vision, slow-healing sores',
        'Headaches, shortness of breath, nosebleeds, dizziness, chest pain',
        'Wheezing, shortness of breath, chest tightness, coughing, difficulty breathing during physical activity',
        'Persistent cough, shortness of breath, wheezing, chest tightness, frequent respiratory infections',
        'Chest pain or discomfort, pain in the shoulder, neck, or jaw, shortness of breath, nausea or vomiting, lightheadedness, cold sweat',
        'Sudden numbness or weakness in the face, arm, or leg, sudden confusion or trouble speaking, sudden trouble seeing, sudden trouble walking, dizziness, loss of balance',
        'Severe headache, nausea, vomiting, sensitivity to light and sound, visual disturbances',
        'Sneezing, runny or stuffy nose, itchy or watery eyes, skin rash or hives, itchy throat or ears',
        'Heartburn, regurgitation, chest pain, difficulty swallowing, chronic cough',
        'Abdominal pain or cramping, bloating, gas, diarrhea or constipation, changes in bowel habits',
        'Joint pain and swelling, morning stiffness, fatigue, fever, weight loss',
        'Joint pain, stiffness, swelling, decreased range of motion, bone spurs',
        'Red patches of skin covered with thick, silvery scales, dry, cracked skin, itching or soreness, swollen and stiff joints',
        'Persistent cough, chest pain, weight loss, fever, night sweats',
        'Fatigue, abdominal pain, loss of appetite, nausea and vomiting, dark urine, jaundice',
        'Fatigue, abdominal pain, loss of appetite, nausea, jaundice, dark urine',
        'Flu-like symptoms, rapid weight loss, recurring fever, persistent cough, night sweats, sores or ulcers',
        'Unexplained weight loss, fever, fatigue, pain, skin changes, persistent cough or hoarseness',
        'Persistent sadness, loss of interest or pleasure, fatigue, changes in appetite or weight, trouble sleeping, feelings of worthlessness',
        'Excessive worry, restlessness, fatigue, difficulty concentrating, muscle tension, sleep disturbances',
        'Delusions, hallucinations, disorganized thinking, negative symptoms',
        'Tremors, muscle rigidity, bradykinesia, postural instability, difficulty with balance',
        'Memory loss, difficulty performing familiar tasks, disorientation, poor judgment, changes in mood and personality', 
        'Cough, fever, chills, shortness of breath, chest pain, fatigue',
        'Cough with mucus, fatigue, shortness of breath, slight fever, chest discomfort',
        'Salty-tasting skin, persistent cough with thick mucus, lung infections, poor growth, difficulty breathing',

        
    ]
}
df = pd.DataFrame(data)

# Convert text data into numerical format
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['symptoms'])
y = df['disease']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

# Train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# Save the model and vectorizer
joblib.dump(model, 'disease_predictor_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')

def predict_diseases(user_symptoms):
    # Load the model and vectorizer
    model = joblib.load('disease_predictor_model.pkl')
    vectorizer = joblib.load('vectorizer.pkl')
    
    # Transform user input symptoms
    user_symptoms_vec = vectorizer.transform([user_symptoms])
    
    # Predict probabilities for each disease
    probabilities = model.predict_proba(user_symptoms_vec)[0]
    
    # Get the indices of the top 3 diseases
    top_indices = np.argsort(probabilities)[-3:][::-1]
    
    # Get the corresponding diseases and their probabilities
    diseases = np.array(model.classes_)[top_indices]
    probs = probabilities[top_indices]
    
    # Format the results
    result = {disease: f"{prob * 100:.2f}% chance" for disease, prob in zip(diseases, probs)}
    return result

# Example usage
user_input = input("Enter your symptoms: ")
predicted_diseases = predict_diseases(user_input)
print("Predicted diseases and their chances:")
for disease, chance in predicted_diseases.items():
    print(f"{disease}: {chance}")
# Out:
# Enter your symptoms:  Runny nose, sore throat, cough, sneezing, mild fever, headache
# Predicted diseases and their chances:
# Common Cold: 69.00% chance
# Allergies: 6.00% chance
# Hypertension: 4.00% chance
